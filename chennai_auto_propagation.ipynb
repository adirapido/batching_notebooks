# %%
#Import libraries
from pyhive import presto
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import h3
from datetime import datetime
from functools import reduce
import json
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
#Define presto credentials
presto_host = 'presto-gateway.serving.data.plectrum.dev'
presto_port = '80'
username = 'aditya.bhattar@rapido.bike'

#Create connection to presto host
connection = presto.connect(presto_host,presto_port,username = username)

# %%
#Query data from order_logs_snapshot

q = """
select yyyymmdd, epoch, data_orderId, data_propagationBatchId, data_riderId, eventType, hh, updated_epoch from raw.kafka_dispatch_propagation_immutable
where data_serviceDetailId = '5f6f201a61f57a0007d2aac4'
and yyyymmdd = '20230620'
and hh in ('17', '18', '19', '20', '21')
and eventType = 'rider_acknowledged'
"""


#Load data into pandas table
df_propagation_copy = pd.read_sql(q, connection)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[4], line 13
#       3 q = """
#       4 select yyyymmdd, epoch, data_orderId, data_propagationBatchId, data_riderId, eventType, hh, updated_epoch from raw.kafka_dispatch_propagation_immutable
#       5 where data_serviceDetailId = '5f6f201a61f57a0007d2aac4'
#    (...)
#       8 and eventType = 'rider_acknowledged'
#       9 """
#      12 #Load data into pandas table
# ---> 13 df_propagation_copy = pd.read_sql(q, connection)
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pandas/io/sql.py:633, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     631 with pandasSQL_builder(con) as pandas_sql:
#     632     if isinstance(pandas_sql, SQLiteDatabase):
# --> 633         return pandas_sql.read_query(
#     634             sql,
#     635             index_col=index_col,
#     636             params=params,
#     637             coerce_float=coerce_float,
#     638             parse_dates=parse_dates,
#     639             chunksize=chunksize,
#     640             dtype_backend=dtype_backend,  # type: ignore[arg-type]
#     641             dtype=dtype,
#     642         )
#     644     try:
#     645         _is_table_name = pandas_sql.has_table(sql)
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pandas/io/sql.py:2279, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2268     return self._query_iterator(
#    2269         cursor,
#    2270         chunksize,
#    (...)
#    2276         dtype_backend=dtype_backend,
#    2277     )
#    2278 else:
# -> 2279     data = self._fetchall_as_list(cursor)
#    2280     cursor.close()
#    2282     frame = _wrap_result(
#    2283         data,
#    2284         columns,
#    (...)
#    2289         dtype_backend=dtype_backend,
#    2290     )
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pandas/io/sql.py:2294, in SQLiteDatabase._fetchall_as_list(self, cur)
#    2293 def _fetchall_as_list(self, cur):
# -> 2294     result = cur.fetchall()
#    2295     if not isinstance(result, list):
#    2296         result = list(result)
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pyhive/common.py:137, in DBAPICursor.fetchall(self)
#     130 def fetchall(self):
#     131     """Fetch all (remaining) rows of a query result, returning them as a sequence of sequences
#     132     (e.g. a list of tuples).
#     133
#     134     An :py:class:`~pyhive.exc.Error` (or subclass) exception is raised if the previous call to
#     135     :py:meth:`execute` did not produce any result set or no call was issued yet.
#     136     """
# --> 137     return list(iter(self.fetchone, None))
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pyhive/common.py:106, in DBAPICursor.fetchone(self)
#     103     raise exc.ProgrammingError("No query yet")
#     105 # Sleep until we're done or we have some data to return
# --> 106 self._fetch_while(lambda: not self._data and self._state != self._STATE_FINISHED)
#     108 if not self._data:
#     109     return None
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pyhive/common.py:46, in DBAPICursor._fetch_while(self, fn)
#      44 def _fetch_while(self, fn):
#      45     while fn():
# ---> 46         self._fetch_more()
#      47         if fn():
#      48             time.sleep(self._poll_interval)
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pyhive/presto.py:315, in Cursor._fetch_more(self)
#     313 def _fetch_more(self):
#     314     """Fetch the next URI and update state"""
# --> 315     self._process_response(self._requests_session.get(self._nextUri, **self._requests_kwargs))
#
# File ~/Desktop/auto_batching/.venv/lib/python3.10/site-packages/pyhive/presto.py:355, in Cursor._process_response(self, response)
#     353     self._state = self._STATE_FINISHED
#     354 if 'error' in response_json:
# --> 355     raise DatabaseError(response_json['error'])
#
# DatabaseError: {'message': 'Query exceeded the maximum execution time limit of 10.00m', 'errorCode': 131075, 'errorName': 'EXCEEDED_TIME_LIMIT', 'errorType': 'INSUFFICIENT_RESOURCES', 'failureInfo': {'type': 'io.trino.spi.TrinoException', 'message': 'Query exceeded the maximum execution time limit of 10.00m', 'suppressed': [], 'stack': ['io.trino.execution.QueryTracker.enforceTimeLimits(QueryTracker.java:187)', 'io.trino.execution.QueryTracker.lambda$start$0(QueryTracker.java:89)', 'com.google.common.util.concurrent.MoreExecutors$ScheduledListeningDecorator$NeverSuccessfulListenableFutureTask.run(MoreExecutors.java:730)', 'java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)', 'java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)', 'java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)', 'java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)', 'java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)', 'java.base/java.lang.Thread.run(Thread.java:829)']}}

# %%
df_propagation = df_propagation_copy.copy()
df_propagation.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_propagation = df_propagation_copy.copy()
#       2 df_propagation.head()
#
# NameError: name 'df_propagation_copy' is not defined

# %%
df_propagation = df_propagation.sort_values(by = ['data_orderId', 'updated_epoch', 'data_propagationBatchId'])
df_propagation.head()
# Out:
#         yyyymmdd          epoch              data_orderId
# 365571  20230620  1687268746824  6490bec9a123ae7aadab2954  \
# 239394  20230620  1687268746824  6490bec9a123ae7aadab2954
# 239035  20230620  1687268746824  6490bec9a123ae7aadab2954
# 411055  20230620  1687268746824  6490bec9a123ae7aadab2954
# 395705  20230620  1687268746824  6490bec9a123ae7aadab2954
#
#                      data_propagationBatchId              data_riderId
# 365571  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  5d6fa257a24c96105e3830a3  \
# 239394  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  6063ee4a57c96919bf9432aa
# 239035  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  5e26b9dc430121028f9c6612
# 411055  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  628c8366024f976497487b1f
# 395705  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  5f8c1a9303ab70327cf61f93
#
#                  eventType  hh  updated_epoch
# 365571  rider_acknowledged  19  1687268749442
# 239394  rider_acknowledged  19  1687268749724
# 239035  rider_acknowledged  19  1687268749976
# 411055  rider_acknowledged  19  1687268750162
# 395705  rider_acknowledged  19  1687268750208

# %%
df_propagation['counter'] = (df_propagation['data_propagationBatchId'] != df_propagation['data_propagationBatchId'].shift()) | (df_propagation['data_orderId'] != df_propagation['data_orderId'].shift())
df_propagation['counter'] = df_propagation.groupby('data_orderId')['counter'].cumsum()
df_propagation.head()
# Out:
#         yyyymmdd          epoch              data_orderId
# 365571  20230620  1687268746824  6490bec9a123ae7aadab2954  \
# 239394  20230620  1687268746824  6490bec9a123ae7aadab2954
# 239035  20230620  1687268746824  6490bec9a123ae7aadab2954
# 411055  20230620  1687268746824  6490bec9a123ae7aadab2954
# 395705  20230620  1687268746824  6490bec9a123ae7aadab2954
#
#                      data_propagationBatchId              data_riderId
# 365571  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  5d6fa257a24c96105e3830a3  \
# 239394  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  6063ee4a57c96919bf9432aa
# 239035  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  5e26b9dc430121028f9c6612
# 411055  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  628c8366024f976497487b1f
# 395705  45101a17-1d9f-403d-ba44-99c7c0b7ca8f  5f8c1a9303ab70327cf61f93
#
#                  eventType  hh  updated_epoch  counter
# 365571  rider_acknowledged  19  1687268749442        1
# 239394  rider_acknowledged  19  1687268749724        1
# 239035  rider_acknowledged  19  1687268749976        1
# 411055  rider_acknowledged  19  1687268750162        1
# 395705  rider_acknowledged  19  1687268750208        1

# %%
df_propagation[df_propagation['']]

# %%
#Query data from order_logs_snapshot

q = """
select order_id, accept_to_pickup_distance, captain_location_hex_8, captain_location_latitude,
captain_location_longitude, city_name, customer_location_hex_8, drop_location_hex_8, drop_location_latitude, drop_location_longitude, customer_location_latitude, 
customer_location_longitude, hhmmss, hour, quarter_hour, service_obj_service_name, time_bucket, weekday, yyyymmdd,
order_status, cancel_reason, updated_epoch, event_type, captain_id, spd_fraud_flag, pickup_location_hex_8, estimated_accept_to_pickup_distance
from orders.order_logs_immutable
where yyyymmdd = '20230620'
and service_obj_service_name = 'Auto'
and event_type in ('accepted', 'rider_busy', 'rider_reject')
and city_name = 'Chennai'
and hour in ('17', '18', '19', '20', '21')
"""

#Load data into pandas table
df_apr_copy = pd.read_sql(q, connection)

# %%
df_apr = df_apr_copy.copy()
df_apr.head()
# Out:
#                    order_id  accept_to_pickup_distance captain_location_hex_8
# 0  6491d2a32b1dca469bf3395e                      0.904        88618c4d01fffff  \
# 1  6491d35fe205f470687a26ec                        NaN        88618c4599fffff
# 2  6491d3b1b2f49b01869c978e                        NaN        88618c4883fffff
# 3  6491d3c8a123ae7aadace9cb                        NaN        88618c4983fffff
# 4  6491d3e0a6877d27a7b11061                        NaN        88618eb211fffff
#
#    captain_location_latitude  captain_location_longitude city_name
# 0                  13.077112                   80.211275   Chennai  \
# 1                  12.905248                   80.093315   Chennai
# 2                  13.075551                   80.258965   Chennai
# 3                  13.127195                   80.290833   Chennai
# 4                  13.125738                   80.219789   Chennai
#
#   customer_location_hex_8 drop_location_hex_8  drop_location_latitude
# 0         88618c4d0dfffff     88618eb251fffff               13.111258  \
# 1         88618c4599fffff     88618c4539fffff               12.927058
# 2         88618c48b9fffff     88618c4087fffff               12.926758
# 3         88618c498bfffff     88618c4993fffff               13.124261
# 4         88618eb21dfffff     88618eb257fffff               13.118817
#
#    drop_location_longitude  customer_location_latitude
# 0                80.232650                   13.082111  \
# 1                80.157849                   12.905214
# 2                80.229769                   13.080353
# 3                80.265104                   13.119203
# 4                80.231121                   13.119601
#
#    customer_location_longitude  hhmmss hour quarter_hour
# 0                    80.215485  215403   21         2145  \
# 1                    80.095749  215711   21         2145
# 2                    80.255241  215833   21         2145
# 3                    80.293121  215856   21         2145
# 4                    80.226158  215920   21         2145
#
#   service_obj_service_name time_bucket  weekday  yyyymmdd order_status
# 0                     Auto       21:59        2  20230620          new  \
# 1                     Auto       21:59        2  20230620          new
# 2                     Auto       21:59        2  20230620          new
# 3                     Auto       21:59        2  20230620          new
# 4                     Auto       21:59        2  20230620          new
#
#              cancel_reason  updated_epoch    event_type
# 0  Unable to swipe Arrived  1687278365408    rider_busy  \
# 1                     None  1687278438438  rider_reject
# 2                     None  1687278531134  rider_reject
# 3                     None  1687278543210  rider_reject
# 4                     None  1687278586425    rider_busy
#
#                  captain_id spd_fraud_flag pickup_location_hex_8
# 0  61ea705eced193995bb37c2c           None       88618c4d0dfffff  \
# 1  6321cfdf950ab9d554fd1ec7           None       88618c4599fffff
# 2  5f8ed50a15b87f206487450e           None       88618c48b9fffff
# 3  5fec1736857d1b68232191e4           None       88618c498bfffff
# 4  63bc15c859ea2c1d09f44683           None       88618eb21dfffff
#
#    estimated_accept_to_pickup_distance
# 0                                972.3
# 1                               1498.7
# 2                                943.1
# 3                               1392.2
# 4                                927.9

# %%
df_propagation = df_propagation.rename(columns = {'data_orderId':'order_id', 'data_riderId':'captain_id'})
df_propagation_filter = df_propagation[['order_id', 'captain_id', 'counter']]
df_propagation_filter = df_propagation_filter.drop_duplicates()
df_apr = df_apr.merge(df_propagation_filter, on = ['order_id', 'captain_id'], how = 'left')
df_accepted = df_apr[df_apr['event_type'] == 'accepted']
df_accepted.head()
# Out:
#                     order_id  accept_to_pickup_distance
# 10  6491c7676a1bfa2a894a66ba                        NaN  \
# 26  6491cb16108c23086d1104c1                        NaN
# 28  6491cc65afae71062c262354                        NaN
# 33  6491d1bee205f470687a24e4                        NaN
# 49  6491d35d2b1dca469bf33a49                        NaN
#
#    captain_location_hex_8  captain_location_latitude
# 10        88618c4f3dfffff                  13.040056  \
# 26        88618c4525fffff                  12.949134
# 28        88618c4d4dfffff                  13.062717
# 33        88618c489dfffff                  13.073170
# 49        88618c4f2bfffff                  13.040654
#
#     captain_location_longitude city_name customer_location_hex_8
# 10                   80.231598   Chennai         88618c4f3dfffff  \
# 26                   80.185898   Chennai         88618c4e53fffff
# 28                   80.229752   Chennai         88618c4d4dfffff
# 33                   80.256149   Chennai         88618c4883fffff
# 49                   80.238609   Chennai         88618c4f3dfffff
#
#    drop_location_hex_8  drop_location_latitude  drop_location_longitude
# 10     88618c4d25fffff               13.105696                80.213783  \
# 26     88618c4ed1fffff               12.951558                80.140022
# 28     88618c4c49fffff               13.005876                80.195800
# 33     88618c4f1dfffff               13.019824                80.224570
# 49     88618c4f25fffff               13.057176                80.248970
#
#     customer_location_latitude  customer_location_longitude  hhmmss hour
# 10                   13.039446                    80.231689  210607   21  \
# 26                   12.949523                    80.194572  212150   21
# 28                   13.062849                    80.230637  212725   21
# 33                   13.073718                    80.256981  215014   21
# 49                   13.041507                    80.232071  215709   21
#
#    quarter_hour service_obj_service_name time_bucket  weekday  yyyymmdd
# 10         2100                     Auto       21:00        2  20230620  \
# 26         2115                     Auto       21:00        2  20230620
# 28         2115                     Auto       21:00        2  20230620
# 33         2145                     Auto       21:59        2  20230620
# 49         2145                     Auto       21:59        2  20230620
#
#    order_status cancel_reason  updated_epoch event_type
# 10     onTheWay          None  1687275373377   accepted  \
# 26     onTheWay          None  1687276320748   accepted
# 28     onTheWay          None  1687276650593   accepted
# 33     onTheWay          None  1687278023705   accepted
# 49     onTheWay          None  1687278445927   accepted
#
#                   captain_id spd_fraud_flag pickup_location_hex_8
# 10  5ce064ed25ee3218d4cef566           None       88618c4f3dfffff  \
# 26  5d73eac6a24c96105e3f5fa2           None       88618c4e53fffff
# 28  6414114747c36bd3a4427725           None       88618c4d4dfffff
# 33  63216768dc7efa1ab317e0a3           None       88618c4883fffff
# 49  63f06c9bdfeed3e02ee36880           None       88618c4f3dfffff
#
#     estimated_accept_to_pickup_distance  counter
# 10                                734.0        1
# 26                               1196.4        1
# 28                                124.5        1
# 33                                 99.1        1
# 49                                979.8        1

# %%
q = """
select * from datasets.hex_adjacency
where city_name = 'chennai'
"""

df_adjacency_copy = pd.read_sql(q, connection)
df_adjacency_copy.head()
# Out:
#                                    uid   dayname   time_period
# 0   88618c45c3fffff-Thursday-afternoon  Thursday     afternoon  \
# 1     88618c4033fffff-Monday-afternoon    Monday     afternoon
# 2  88618c55d9fffff-Monday-evening_peak    Monday  evening_peak
# 3  88618c4ca3fffff-Friday-evening_peak    Friday  evening_peak
# 4  88618c4d1dfffff-Sunday-morning_peak    Sunday  morning_peak
#
#         source_hex                                          adjacency
# 0  88618c45c3fffff  ['88618c45c7fffff', '88618c45c3fffff', '88618c...  \
# 1  88618c4033fffff  ['88618c4037fffff', '88618c40e5fffff', '88618c...
# 2  88618c55d9fffff  ['88618c55dbfffff', '88618c54e5fffff', '88618c...
# 3  88618c4ca3fffff  ['88618c4cb7fffff', '88618eb641fffff', '88618c...
# 4  88618c4d1dfffff  ['88618c4d1dfffff', '88618c4d03fffff', '88618c...
#
#                                     backup_adjacency
# 0  ['88618c45ebfffff', '88618c45d5fffff', '88618c...  \
# 1  ['88618c4037fffff', '88618c4031fffff', '88618c...
# 2  ['88618c55dbfffff', '88618c54e5fffff', '88618c...
# 3  ['88618c4cb7fffff', '88618eb641fffff', '88618c...
# 4  ['88618c4d13fffff', '88618c4d09fffff', '88618c...
#
#                                  type start_ts end_ts
# 0                          2022_reset    12:00  17:00  \
# 1                          2022_reset    12:00  17:00
# 2  chennai_20230327_adjacency_removal    17:00  22:00
# 3  chennai_20230327_adjacency_removal    17:00  22:00
# 4                          2022_reset    08:00  12:00
#
#                     city_id      date propagation_type
# 0  57af2db19729ad145ddbba66  20211030        multicast  \
# 1  57af2db19729ad145ddbba66  20211030        multicast
# 2  57af2db19729ad145ddbba66  20220418        multicast
# 3  57af2db19729ad145ddbba66  20220418        multicast
# 4  57af2db19729ad145ddbba66  20211030        multicast
#
#   propagation_eta_buckets multicast_max_batch_size         service_detail_id
# 0  [[0,6],[6,12],[12,18]]                        4                      None  \
# 1  [[0,6],[6,12],[12,18]]                        4  5c6a8aae49999b598b535917
# 2  [[0,6],[6,12],[12,18]]                        4  5bed473f1278885df4ea9d57
# 3  [[0,6],[6,12],[12,18]]                        4  5bed473f1278885df4ea9d57
# 4  [[0,6],[6,12],[12,18]]                        4                      None
#
#   undesirable_hexes  max_mmo_parallel_order
# 0              None                       3  \
# 1              None                       3
# 2              None                       3
# 3              None                       3
# 4              None                       3
#
#               propagation_score_buckets  on_ride_booking_enabled  pap_enabled
# 0  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False  \
# 1  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
# 2  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
# 3  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
# 4  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
#
#    pap_batch_window_in_ms batch_adjacency
# 0                       5                  \
# 1                       5
# 2                       5
# 3                       5
# 4                       5
#
#    route_preference_eligibility_threshold_score multicast_config city_name
# 0                                           0.0             None   chennai
# 1                                           0.0             None   chennai
# 2                                           0.0             None   chennai
# 3                                           0.0             None   chennai
# 4                                           0.0             None   chennai

# %%
df_adjacency = df_adjacency_copy.copy()
df_adjacency.head()
# Out:
#                                    uid   dayname   time_period
# 0   88618c45c3fffff-Thursday-afternoon  Thursday     afternoon  \
# 1     88618c4033fffff-Monday-afternoon    Monday     afternoon
# 2  88618c55d9fffff-Monday-evening_peak    Monday  evening_peak
# 3  88618c4ca3fffff-Friday-evening_peak    Friday  evening_peak
# 4  88618c4d1dfffff-Sunday-morning_peak    Sunday  morning_peak
#
#         source_hex                                          adjacency
# 0  88618c45c3fffff  ['88618c45c7fffff', '88618c45c3fffff', '88618c...  \
# 1  88618c4033fffff  ['88618c4037fffff', '88618c40e5fffff', '88618c...
# 2  88618c55d9fffff  ['88618c55dbfffff', '88618c54e5fffff', '88618c...
# 3  88618c4ca3fffff  ['88618c4cb7fffff', '88618eb641fffff', '88618c...
# 4  88618c4d1dfffff  ['88618c4d1dfffff', '88618c4d03fffff', '88618c...
#
#                                     backup_adjacency
# 0  ['88618c45ebfffff', '88618c45d5fffff', '88618c...  \
# 1  ['88618c4037fffff', '88618c4031fffff', '88618c...
# 2  ['88618c55dbfffff', '88618c54e5fffff', '88618c...
# 3  ['88618c4cb7fffff', '88618eb641fffff', '88618c...
# 4  ['88618c4d13fffff', '88618c4d09fffff', '88618c...
#
#                                  type start_ts end_ts
# 0                          2022_reset    12:00  17:00  \
# 1                          2022_reset    12:00  17:00
# 2  chennai_20230327_adjacency_removal    17:00  22:00
# 3  chennai_20230327_adjacency_removal    17:00  22:00
# 4                          2022_reset    08:00  12:00
#
#                     city_id      date propagation_type
# 0  57af2db19729ad145ddbba66  20211030        multicast  \
# 1  57af2db19729ad145ddbba66  20211030        multicast
# 2  57af2db19729ad145ddbba66  20220418        multicast
# 3  57af2db19729ad145ddbba66  20220418        multicast
# 4  57af2db19729ad145ddbba66  20211030        multicast
#
#   propagation_eta_buckets multicast_max_batch_size         service_detail_id
# 0  [[0,6],[6,12],[12,18]]                        4                      None  \
# 1  [[0,6],[6,12],[12,18]]                        4  5c6a8aae49999b598b535917
# 2  [[0,6],[6,12],[12,18]]                        4  5bed473f1278885df4ea9d57
# 3  [[0,6],[6,12],[12,18]]                        4  5bed473f1278885df4ea9d57
# 4  [[0,6],[6,12],[12,18]]                        4                      None
#
#   undesirable_hexes  max_mmo_parallel_order
# 0              None                       3  \
# 1              None                       3
# 2              None                       3
# 3              None                       3
# 4              None                       3
#
#               propagation_score_buckets  on_ride_booking_enabled  pap_enabled
# 0  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False  \
# 1  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
# 2  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
# 3  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
# 4  [[-1,-0.5],[-0.5,0],[0,0.5],[0.5,1]]                    False        False
#
#    pap_batch_window_in_ms batch_adjacency
# 0                       5                  \
# 1                       5
# 2                       5
# 3                       5
# 4                       5
#
#    route_preference_eligibility_threshold_score multicast_config city_name
# 0                                           0.0             None   chennai
# 1                                           0.0             None   chennai
# 2                                           0.0             None   chennai
# 3                                           0.0             None   chennai
# 4                                           0.0             None   chennai

# %%
df_adjacency_filter = df_adjacency[(df_adjacency['time_period'] == 'evening_peak') & (df_adjacency['service_detail_id'] == '5f6f201a61f57a0007d2aac4')]
df_adjacency_filter = df_adjacency_filter[['source_hex', 'multicast_max_batch_size']]
df_adjacency_filter = df_adjacency_filter.drop_duplicates()
df_adjacency_filter = df_adjacency_filter.rename(columns = {'source_hex':'pickup_location_hex_8'})
df_adjacency_filter.head()
# Out:
#      pickup_location_hex_8 multicast_max_batch_size
# 1036       88618c40a9fffff                       10
# 1038       88618c4d5bfffff                       10
# 1276       88618c49b1fffff                       10
# 1278       88618eb36bfffff                       10
# 1406       88618c4e89fffff                       10

# %%
df_accepted = df_accepted.merge(df_adjacency_filter, on = 'pickup_location_hex_8', how = 'left')
df_accepted.head()
# Out:
#                    order_id  accept_to_pickup_distance captain_location_hex_8
# 0  6491c7676a1bfa2a894a66ba                        NaN        88618c4f3dfffff  \
# 1  6491cb16108c23086d1104c1                        NaN        88618c4525fffff
# 2  6491cc65afae71062c262354                        NaN        88618c4d4dfffff
# 3  6491d1bee205f470687a24e4                        NaN        88618c489dfffff
# 4  6491d35d2b1dca469bf33a49                        NaN        88618c4f2bfffff
#
#    captain_location_latitude  captain_location_longitude city_name
# 0                  13.040056                   80.231598   Chennai  \
# 1                  12.949134                   80.185898   Chennai
# 2                  13.062717                   80.229752   Chennai
# 3                  13.073170                   80.256149   Chennai
# 4                  13.040654                   80.238609   Chennai
#
#   customer_location_hex_8 drop_location_hex_8  drop_location_latitude
# 0         88618c4f3dfffff     88618c4d25fffff               13.105696  \
# 1         88618c4e53fffff     88618c4ed1fffff               12.951558
# 2         88618c4d4dfffff     88618c4c49fffff               13.005876
# 3         88618c4883fffff     88618c4f1dfffff               13.019824
# 4         88618c4f3dfffff     88618c4f25fffff               13.057176
#
#    drop_location_longitude  customer_location_latitude
# 0                80.213783                   13.039446  \
# 1                80.140022                   12.949523
# 2                80.195800                   13.062849
# 3                80.224570                   13.073718
# 4                80.248970                   13.041507
#
#    customer_location_longitude  hhmmss hour quarter_hour
# 0                    80.231689  210607   21         2100  \
# 1                    80.194572  212150   21         2115
# 2                    80.230637  212725   21         2115
# 3                    80.256981  215014   21         2145
# 4                    80.232071  215709   21         2145
#
#   service_obj_service_name time_bucket  weekday  yyyymmdd order_status
# 0                     Auto       21:00        2  20230620     onTheWay  \
# 1                     Auto       21:00        2  20230620     onTheWay
# 2                     Auto       21:00        2  20230620     onTheWay
# 3                     Auto       21:59        2  20230620     onTheWay
# 4                     Auto       21:59        2  20230620     onTheWay
#
#   cancel_reason  updated_epoch event_type                captain_id
# 0          None  1687275373377   accepted  5ce064ed25ee3218d4cef566  \
# 1          None  1687276320748   accepted  5d73eac6a24c96105e3f5fa2
# 2          None  1687276650593   accepted  6414114747c36bd3a4427725
# 3          None  1687278023705   accepted  63216768dc7efa1ab317e0a3
# 4          None  1687278445927   accepted  63f06c9bdfeed3e02ee36880
#
#   spd_fraud_flag pickup_location_hex_8  estimated_accept_to_pickup_distance
# 0           None       88618c4f3dfffff                                734.0  \
# 1           None       88618c4e53fffff                               1196.4
# 2           None       88618c4d4dfffff                                124.5
# 3           None       88618c4883fffff                                 99.1
# 4           None       88618c4f3dfffff                                979.8
#
#    counter multicast_max_batch_size
# 0        1                       10
# 1        1                       10
# 2        1                       10
# 3        1                       10
# 4        1                       10

# %%
batch_wise_acceptance = df_accepted.groupby(['multicast_max_batch_size', 'counter']).size().reset_index()
batch_wise_acceptance = batch_wise_acceptance.rename(columns = {0:'accepted_pings'})
batch_wise_acceptance2 = batch_wise_acceptance.groupby(['multicast_max_batch_size'])['accepted_pings'].sum().reset_index()
batch_wise_acceptance2 = batch_wise_acceptance2.rename(columns = {'accepted_pings':'total_accepted_pings'})
batch_wise_acceptance = batch_wise_acceptance.merge(batch_wise_acceptance2, on = 'multicast_max_batch_size', how = 'left')
batch_wise_acceptance
# Out:
#    multicast_max_batch_size  counter  accepted_pings  total_accepted_pings
# 0                        10        1           13221                 22310
# 1                        10        2            4329                 22310
# 2                        10        3            2259                 22310
# 3                        10        4            1269                 22310
# 4                        10        5             708                 22310
# 5                        10        6             234                 22310
# 6                        10        7             126                 22310
# 7                        10        8              70                 22310
# 8                        10        9              43                 22310
# 9                        10       10              20                 22310
# 10                       10       11              12                 22310
# 11                       10       12               7                 22310
# 12                       10       13               7                 22310
# 13                       10       14               3                 22310
# 14                       10       15               1                 22310
# 15                       10       16               1                 22310

# %%
batch_wise_acceptance.to_csv('chennai_batch_wise_acceptance.csv', index = False)

# %%
batch_wise_acceptance = pd.DataFrame(df_accepted['counter'].value_counts().reset_index())
batch_wise_acceptance.columns = ['batch_number', 'accepted_pings']
batch_wise_acceptance['total_accepted_pings'] = df_accepted.shape[0]
batch_wise_acceptance['%_of_accepted_pings'] = round(batch_wise_acceptance['accepted_pings']/batch_wise_acceptance['total_accepted_pings'], 4)
batch_wise_acceptance
# Out:
#     batch_number  accepted_pings  total_accepted_pings  %_of_accepted_pings
# 0              1           13203                 24321               0.5429
# 1              2            4850                 24321               0.1994
# 2              3            2917                 24321               0.1199
# 3              4            1760                 24321               0.0724
# 4              5            1013                 24321               0.0417
# 5              6             292                 24321               0.0120
# 6              7             128                 24321               0.0053
# 7              8              62                 24321               0.0025
# 8              9              45                 24321               0.0019
# 9             10              20                 24321               0.0008
# 10            11              10                 24321               0.0004
# 11            12               8                 24321               0.0003
# 12            13               5                 24321               0.0002
# 13            14               3                 24321               0.0001
# 14            17               2                 24321               0.0001
# 15            15               1                 24321               0.0000
# 16            19               1                 24321               0.0000
# 17            21               1                 24321               0.0000

# %%
batch_wise_acceptance.to_csv('chennai_batch_wise_acceptance.csv', index = False)

# %%
df_propagation.head(20)
# Out:
#         yyyymmdd          epoch              data_orderId
# 393665  20230510  1683726307914  645a6ddc8b51b47a8f1d567f  \
# 543576  20230510  1683726307998  645a6ddc8b51b47a8f1d567f
# 398398  20230510  1683726309114  645a6ddc8b51b47a8f1d567f
# 414195  20230510  1683726309676  645a6ddc8b51b47a8f1d567f
# 509157  20230510  1683726310208  645a6ddc8b51b47a8f1d567f
# 391033  20230510  1683726917417  645b0c66908b9d588b5dc66f
# 192147  20230510  1683722143183  645b2178af0d3209d269c3df
# 549634  20230510  1683730536871  645b39b670e5ce05969bf500
# 7989    20230510  1683730692786  645b39b670e5ce05969bf500
# 254495  20230510  1683730581854  645b39b670e5ce05969bf500
# 8114    20230510  1683730633270  645b39b670e5ce05969bf500
# 425874  20230510  1683727728222  645b44fd6a343d115be9fd54
# 305001  20230510  1683727647437  645b44fd6a343d115be9fd54
# 122519  20230510  1683718508127  645b58496a343d115bea250f
# 48055   20230510  1683718510818  645b58496a343d115bea250f
# 657316  20230510  1683718561910  645b58496a343d115bea250f
# 123231  20230510  1683718565758  645b58496a343d115bea250f
# 633829  20230510  1683718565759  645b58496a343d115bea250f
# 663924  20230510  1683718566734  645b58496a343d115bea250f
# 631732  20230510  1683718566998  645b58496a343d115bea250f
#
#                      data_propagationBatchId              data_riderId
# 393665  b8f09de1-5612-4e26-afdd-9b838e627092  60e99160e5cb35adea5900ff  \
# 543576  b8f09de1-5612-4e26-afdd-9b838e627092  5ebaca21350aa75c87bb7f34
# 398398  b8f09de1-5612-4e26-afdd-9b838e627092  632bf4134bdbff70462cb037
# 414195  b8f09de1-5612-4e26-afdd-9b838e627092  6319d9882badab5c7d3a3a5e
# 509157  b8f09de1-5612-4e26-afdd-9b838e627092  60295c2a19e4984b6c1e9771
# 391033  fe0cf86e-ce13-4337-af6d-6afb5855c10e  642bffc70e17959cf78df534
# 192147  ebe83566-7f3a-4ebd-972a-bd9518290712  60f121df8bb15d81b65193f2
# 549634  8c3ec9be-8897-4e47-b353-6497fd241810  62ac9b667d79671ecaeba24e
# 7989    a7480d15-da57-4ff1-a354-605b2bc41723  6436b932303d7e7a54697cf4
# 254495  d17d70cd-14b1-497a-bab0-8211fb07640b  62ac9b667d79671ecaeba24e
# 8114    e7ab4ae1-d2e8-4f8f-92c6-731f2e7f8745  63679e3285b39928fa5bab11
# 425874  6324e575-64f6-4862-93ee-a19510ecbb75  6152cdbff2602c79932d7463
# 305001  64ef9cfe-4c86-463c-863e-fde6abf34d90  6152cdbff2602c79932d7463
# 122519  43e68f94-3337-432a-a335-936df008729d  612f4d369db16be23eee4d65
# 48055   43e68f94-3337-432a-a335-936df008729d  61a3654917dd6a3ef303e0c6
# 657316  e3964cc1-d93b-4ba2-a8f9-847f34f83f92  5b38bc21b0e9377f1cc9fc1f
# 123231  e3964cc1-d93b-4ba2-a8f9-847f34f83f92  60e826fe09aa9936cc4318e1
# 633829  e3964cc1-d93b-4ba2-a8f9-847f34f83f92  63c909a8f54ccf1c8ca42253
# 663924  e3964cc1-d93b-4ba2-a8f9-847f34f83f92  630723aaec8781ee34ae5baa
# 631732  e3964cc1-d93b-4ba2-a8f9-847f34f83f92  5cb367e154bc7263ff393eb0
#
#                  eventType  hh  updated_epoch  counter
# 393665  rider_acknowledged  19  1683726307914        1
# 543576  rider_acknowledged  19  1683726307998        1
# 398398  rider_acknowledged  19  1683726309114        1
# 414195  rider_acknowledged  19  1683726309676        1
# 509157  rider_acknowledged  19  1683726310208        1
# 391033  rider_acknowledged  19  1683726917417        1
# 192147  rider_acknowledged  18  1683722143183        1
# 549634  rider_acknowledged  20  1683730536871        1
# 7989    rider_acknowledged  20  1683730692786        2
# 254495  rider_acknowledged  20  1683730581854        3
# 8114    rider_acknowledged  20  1683730633270        4
# 425874  rider_acknowledged  19  1683727728222        1
# 305001  rider_acknowledged  19  1683727647437        2
# 122519  rider_acknowledged  17  1683718508127        1
# 48055   rider_acknowledged  17  1683718510818        1
# 657316  rider_acknowledged  17  1683718561910        2
# 123231  rider_acknowledged  17  1683718565758        2
# 633829  rider_acknowledged  17  1683718565759        2
# 663924  rider_acknowledged  17  1683718566734        2
# 631732  rider_acknowledged  17  1683718566998        2

# %%
df_propagation[df_propagation['data_propagationBatchId'] == 'b8f09de1-5612-4e26-afdd-9b838e627092']
# Out:
#         yyyymmdd          epoch              data_orderId
# 393665  20230510  1683726307914  645a6ddc8b51b47a8f1d567f  \
# 543576  20230510  1683726307998  645a6ddc8b51b47a8f1d567f
# 398398  20230510  1683726309114  645a6ddc8b51b47a8f1d567f
# 414195  20230510  1683726309676  645a6ddc8b51b47a8f1d567f
# 509157  20230510  1683726310208  645a6ddc8b51b47a8f1d567f
#
#                      data_propagationBatchId              data_riderId
# 393665  b8f09de1-5612-4e26-afdd-9b838e627092  60e99160e5cb35adea5900ff  \
# 543576  b8f09de1-5612-4e26-afdd-9b838e627092  5ebaca21350aa75c87bb7f34
# 398398  b8f09de1-5612-4e26-afdd-9b838e627092  632bf4134bdbff70462cb037
# 414195  b8f09de1-5612-4e26-afdd-9b838e627092  6319d9882badab5c7d3a3a5e
# 509157  b8f09de1-5612-4e26-afdd-9b838e627092  60295c2a19e4984b6c1e9771
#
#                  eventType  hh  updated_epoch  counter
# 393665  rider_acknowledged  19  1683726307914        1
# 543576  rider_acknowledged  19  1683726307998        1
# 398398  rider_acknowledged  19  1683726309114        1
# 414195  rider_acknowledged  19  1683726309676        1
# 509157  rider_acknowledged  19  1683726310208        1

# %%
captains_pinged_per_batch = df_propagation.groupby(['data_propagationBatchId'])['data_riderId'].nunique().reset_index()
captains_pinged_per_batch = captains_pinged_per_batch.rename(columns = {'data_riderId':'captains_pinged'})
df_propagation_unique = df_propagation[['data_propagationBatchId', 'counter']]
df_propagation_unique = df_propagation_unique.drop_duplicates()
captains_pinged_per_batch = captains_pinged_per_batch.merge(df_propagation_unique, on = 'data_propagationBatchId', how = 'left')
captains_pinged_per_batch.head()
# Out:
#                 data_propagationBatchId  captains_pinged  counter
# 0  00000fcb-368c-4802-9bcd-94bc5621dacf                1        1
# 1  00003e40-737e-4dbc-996a-4274bc48d782                2        1
# 2  00005ce3-c170-4138-ba7d-2505706c7a0e                2        1
# 3  000077c0-fd84-4fb4-b588-52489a01d9b8               10        1
# 4  000092fc-2f8b-492a-af0b-a0e76e7866e9                1        1

# %%
captains_pinged_per_batch.groupby(['counter'])['captains_pinged'].mean().reset_index()
# Out:
#     counter  captains_pinged
# 0         1         1.905736
# 1         2         1.782025
# 2         3         1.762390
# 3         4         1.801321
# 4         5         1.858209
# 5         6         1.688690
# 6         7         1.731382
# 7         8         1.753266
# 8         9         1.717557
# 9        10         1.775281
# 10       11         1.857143
# 11       12         1.777778
# 12       13         1.600000
# 13       14         2.250000

# %%
df_propagation['counter'] = (df_propagation['data_propagationBatchId'] != df_propagation['data_propagationBatchId'].shift()) | (df_propagation['data_orderId'] != df_propagation['data_orderId'].shift())
df_propagation['counter'] = df_propagation.groupby('data_orderId')['counter'].cumsum()
df_propagation.head()
# Out:
#         yyyymmdd          epoch              data_orderId
# 400155  20230510  1683726307914  645a6ddc8b51b47a8f1d567f  \
# 242489  20230510  1683726307998  645a6ddc8b51b47a8f1d567f
# 240032  20230510  1683726309114  645a6ddc8b51b47a8f1d567f
# 229761  20230510  1683726309676  645a6ddc8b51b47a8f1d567f
# 482423  20230510  1683726310208  645a6ddc8b51b47a8f1d567f
#
#                      data_propagationBatchId              data_riderId
# 400155  b8f09de1-5612-4e26-afdd-9b838e627092  60e99160e5cb35adea5900ff  \
# 242489  b8f09de1-5612-4e26-afdd-9b838e627092  5ebaca21350aa75c87bb7f34
# 240032  b8f09de1-5612-4e26-afdd-9b838e627092  632bf4134bdbff70462cb037
# 229761  b8f09de1-5612-4e26-afdd-9b838e627092  6319d9882badab5c7d3a3a5e
# 482423  b8f09de1-5612-4e26-afdd-9b838e627092  60295c2a19e4984b6c1e9771
#
#                  eventType  hh  counter
# 400155  rider_acknowledged  19        1
# 242489  rider_acknowledged  19        1
# 240032  rider_acknowledged  19        1
# 229761  rider_acknowledged  19        1
# 482423  rider_acknowledged  19        1

# %%
df_propagation_filter = df_propagation[['data_orderId', 'data_riderId', 'counter']]
df_propagation_filter.head()
# Out:
#                     data_orderId              data_riderId  counter
# 400155  645a6ddc8b51b47a8f1d567f  60e99160e5cb35adea5900ff        1
# 242489  645a6ddc8b51b47a8f1d567f  5ebaca21350aa75c87bb7f34        1
# 240032  645a6ddc8b51b47a8f1d567f  632bf4134bdbff70462cb037        1
# 229761  645a6ddc8b51b47a8f1d567f  6319d9882badab5c7d3a3a5e        1
# 482423  645a6ddc8b51b47a8f1d567f  60295c2a19e4984b6c1e9771        1

# %%
#Merge this on df
df_propagation_filter = df_propagation_filter.rename(columns = {'data_orderId':'order_id', 'data_riderId':'captain_id'})
df = df.merge(df_propagation_filter, on = ['order_id', 'captain_id'], how = 'left')
df.head()
# Out:
#                    order_id  accept_to_pickup_distance  city_name
# 0  645bae48bc677762c758e7c3                        NaN  Bangalore  \
# 1  645bae4bde453b02ef33750e                        NaN  Bangalore
# 2  645bae58888565720ae938e6                        NaN  Bangalore
# 3  645baf8b888565720ae93b0d                      0.438  Bangalore
# 4  645bb05bb70c5170c58d75f8                        NaN  Bangalore
#
#   customer_location_hex_8  customer_location_latitude
# 0         8861892591fffff                   12.930825  \
# 1         8861892513fffff                   12.931752
# 2         8861892433fffff                   12.906545
# 3         88618925ddfffff                   12.921208
# 4         88618925c1fffff                   12.923099
#
#    customer_location_longitude  hhmmss hour quarter_hour
# 0                    77.580872  201632   20         2015  \
# 1                    77.634494  201635   20         2015
# 2                    77.606756  201648   20         2015
# 3                    77.604073  202155   20         2015
# 4                    77.620018  202523   20         2015
#
#   service_obj_service_name time_bucket  weekday  yyyymmdd       order_status
# 0                     Auto       20:00        3  20230510            expired  \
# 1                     Auto       20:00        3  20230510            expired
# 2                     Auto       20:00        3  20230510  customerCancelled
# 3                     Auto       20:00        3  20230510            dropped
# 4                     Auto       20:00        3  20230510            expired
#
#                            cancel_reason  eta
# 0                                   None  7.0  \
# 1                                   None  2.0
# 2  order cancelled before rider accepted  2.0
# 3                                   None  2.0
# 4                                   None  0.0
#
#                                           map_riders pickup_location_hex_8
# 0  ["60ed2fb613ae1d748eb5528a","6013ae76edd74b702...       8861892591fffff  \
# 1  ["60f40f138f3479e752195633","63b683460e10cd5a3...       8861892513fffff
# 2  ["60685591a2f9c56b225129b7","62578fdd00b5f49e5...       8861892433fffff
# 3  ["62921b26444fa9ba4f782075","610a4a8a06f56f41f...       88618925ddfffff
# 4  ["6442088be2719e34f0671600","62578fdd00b5f49e5...       88618925c1fffff
#
#                  captain_id  estimated_accept_to_pickup_distance  counter
# 0  62a072577d796770ede1fe5f                               1060.2      2.0
# 1  63d405e015a98c9f1f0db9af                               1882.5      6.0
# 2                                                            NaN      NaN
# 3  631b7e788276172360bbb215                                  NaN      1.0
# 4  6442088be2719e34f0671600                               1122.7      1.0

# %%
df['counter'] = df['counter'].fillna(1)
df['counter_group'] = np.where(df['counter'] >= 5, '5 or more batches', df['counter'])
df.head()
# Out:
#                    order_id  accept_to_pickup_distance  city_name
# 0  645bae48bc677762c758e7c3                        NaN  Bangalore  \
# 1  645bae4bde453b02ef33750e                        NaN  Bangalore
# 2  645bae58888565720ae938e6                        NaN  Bangalore
# 3  645baf8b888565720ae93b0d                      0.438  Bangalore
# 4  645bb05bb70c5170c58d75f8                        NaN  Bangalore
#
#   customer_location_hex_8  customer_location_latitude
# 0         8861892591fffff                   12.930825  \
# 1         8861892513fffff                   12.931752
# 2         8861892433fffff                   12.906545
# 3         88618925ddfffff                   12.921208
# 4         88618925c1fffff                   12.923099
#
#    customer_location_longitude  hhmmss hour quarter_hour
# 0                    77.580872  201632   20         2015  \
# 1                    77.634494  201635   20         2015
# 2                    77.606756  201648   20         2015
# 3                    77.604073  202155   20         2015
# 4                    77.620018  202523   20         2015
#
#   service_obj_service_name time_bucket  weekday  yyyymmdd       order_status
# 0                     Auto       20:00        3  20230510            expired  \
# 1                     Auto       20:00        3  20230510            expired
# 2                     Auto       20:00        3  20230510  customerCancelled
# 3                     Auto       20:00        3  20230510            dropped
# 4                     Auto       20:00        3  20230510            expired
#
#                            cancel_reason  eta
# 0                                   None  7.0  \
# 1                                   None  2.0
# 2  order cancelled before rider accepted  2.0
# 3                                   None  2.0
# 4                                   None  0.0
#
#                                           map_riders pickup_location_hex_8
# 0  ["60ed2fb613ae1d748eb5528a","6013ae76edd74b702...       8861892591fffff  \
# 1  ["60f40f138f3479e752195633","63b683460e10cd5a3...       8861892513fffff
# 2  ["60685591a2f9c56b225129b7","62578fdd00b5f49e5...       8861892433fffff
# 3  ["62921b26444fa9ba4f782075","610a4a8a06f56f41f...       88618925ddfffff
# 4  ["6442088be2719e34f0671600","62578fdd00b5f49e5...       88618925c1fffff
#
#                  captain_id  estimated_accept_to_pickup_distance  counter
# 0  62a072577d796770ede1fe5f                               1060.2      2.0  \
# 1  63d405e015a98c9f1f0db9af                               1882.5      6.0
# 2                                                            NaN      1.0
# 3  631b7e788276172360bbb215                                  NaN      1.0
# 4  6442088be2719e34f0671600                               1122.7      1.0
#
#        counter_group
# 0                2.0
# 1  5 or more batches
# 2                1.0
# 3                1.0
# 4                1.0

# %%
#Filter only on the hexes needed
df_filter_level1 = df
df_filter_level1['count'] = 1
df_filter_level1['date'] = df_filter_level1['yyyymmdd'].astype(str).apply(lambda x: x[6:])

# %%
#Create a new column for cancel_reason to identify OCARA
df_filter_level1['new_cancel_reason'] = np.where(df_filter_level1['order_status'] == 'customerCancelled',
 np.where(df_filter_level1['cancel_reason'] == 'order cancelled before rider accepted', 'COBRA',
 np.where(df_filter_level1['cancel_reason'] == 'Order cancelled before rider was mapped', 'COBRM', 'OCARA')), 'no_cancellation')

# %%
#Check if the order is expiry_mapped or expiry_unmapped
df_filter_level1['expiry_type'] = np.where(df_filter_level1['order_status'] == 'expired',
 np.where(df_filter_level1['map_riders'] == '[]', 'expiry_unmapped', 'expiry_mapped'), 'no_expiry')
df_filter_level1['final_order_status'] = np.where(df_filter_level1['order_status'] == 'customerCancelled', df_filter_level1['new_cancel_reason'],
np.where(df_filter_level1['order_status'] == 'expired', df_filter_level1['expiry_type'], df_filter_level1['order_status']))

# %%
order_status = df_filter_level1[df_filter_level1['counter_group'] == '2.0']
order_status = order_status[['order_id', 'final_order_status']]

# %%
#Query data from order_logs_snapshot

q = """
select order_id, accept_to_pickup_distance, city_name, customer_location_hex_8, customer_location_latitude, 
customer_location_longitude, hhmmss, hour, quarter_hour, service_obj_service_name, time_bucket, weekday, yyyymmdd,
order_status, cancel_reason, eta, map_riders, pickup_location_hex_8, captain_id, estimated_accept_to_pickup_distance, updated_epoch, event_type
from orders.order_logs_immutable
where yyyymmdd = '20230510'
and city_name in ('Bangalore')
and service_obj_service_name = 'Auto'
and pickup_location_hex_8 in ('8861892433fffff', '886189251bfffff', '88618925c3fffff', '8861892589fffff', '886189242dfffff', '8861892421fffff', '88618925d3fffff',
 '88618925cdfffff', '88618925d1fffff', '886189255bfffff', '8861892553fffff', '88618925d5fffff', '88618925e3fffff', '88618925ebfffff', '88618924adfffff',
   '8861892513fffff', '88618924e7fffff', '88618925c5fffff', '88618925dbfffff', '88618925ddfffff', '88618925c7fffff', '88618924a5fffff', '88618924e5fffff',
     '88618925c9fffff', '8861892599fffff', '88618925d9fffff', '8861892437fffff', '88618925e9fffff', '88618925d7fffff', '88618925c1fffff', '8861892591fffff',
       '88618925cbfffff', '8861892581fffff', '8861892431fffff', '886189259dfffff', '886189258dfffff', '886189258bfffff', '886189259bfffff', '8861892435fffff',
         '8861892517fffff', '88618925e1fffff', '88618925edfffff', '88618925e7fffff')
and hour in ('17', '18', '19', '20', '21')
and event_type in ('accepted', 'rider_busy', 'rider_reject')
"""


#Load data into pandas table
df_copy = pd.read_sql(q, connection)

# %%
df_copy = df_copy.merge(order_status, on = 'order_id', how = 'left')
df_copy.head()
# Out:
#                    order_id  accept_to_pickup_distance  city_name
# 0  645bc55913c08a4ec9300ca1                        NaN  Bangalore  \
# 1  645bba478dbcb75a89aaf31b                        NaN  Bangalore
# 2  645bc5db612b712367f9b7c6                        NaN  Bangalore
# 3  645bc5f3612b712367f9b7ee                        NaN  Bangalore
# 4  645bb892888565720ae94a6f                        NaN  Bangalore
#
#   customer_location_hex_8  customer_location_latitude
# 0         8861892437fffff                   12.910453  \
# 1         8861892589fffff                   12.933781
# 2         88618925c7fffff                   12.935354
# 3         88618925d7fffff                   12.929103
# 4         8861892c19fffff                   13.030947
#
#    customer_location_longitude  hhmmss hour quarter_hour
# 0                    77.612503  215457   21         2145  \
# 1                    77.608307  210743   21         2100
# 2                    77.614131  215707   21         2145
# 3                    77.591507  215731   21         2145
# 4                    77.648964  210026   21         2100
#
#   service_obj_service_name time_bucket  weekday  yyyymmdd order_status
# 0                     Auto       21:59        3  20230510          new  \
# 1                     Auto       21:00        3  20230510          new
# 2                     Auto       21:59        3  20230510          new
# 3                     Auto       21:59        3  20230510          new
# 4                     Auto       21:00        3  20230510          new
#
#   cancel_reason  eta                                         map_riders
# 0          None  2.0  ["629f19df1b57e4adbae9f447","61fe1f9c725c4cea8...  \
# 1          None  0.0  ["62d3f19e32a921678d77579e","642e67c41ecc3a9b6...
# 2          None  3.0  ["60e94a1fac6ff47ed860ad5f","62d4cf8a24fad3312...
# 3          None  0.0  ["5e5503e9dcc6a7fda2a2e67f","60e44ebf09aa996cb...
# 4          None  1.0  ["62d793f9ceb77701571006bc","62b1760317af9a1ea...
#
#   pickup_location_hex_8                captain_id
# 0       8861892437fffff  62cbb9b801d28934302b9682  \
# 1       8861892589fffff  62d3f19e32a921678d77579e
# 2       88618925c7fffff  6151938cf2602c3cb62cabc4
# 3       88618925d7fffff  60e44ebf09aa996cbb41180b
# 4       88618925e7fffff  6295caae74c07130cc508775
#
#    estimated_accept_to_pickup_distance  updated_epoch    event_type
# 0                               1214.4  1683735926040    rider_busy  \
# 1                                437.9  1683733123970    rider_busy
# 2                                953.6  1683736130433  rider_reject
# 3                               1090.9  1683736141453    rider_busy
# 4                                589.7  1683732663471    rider_busy
#
#   final_order_status
# 0      expiry_mapped
# 1                NaN
# 2                NaN
# 3                NaN
# 4      expiry_mapped

# %%
df_copy = df_copy.dropna()
df_copy.head()
# Out:
#                       order_id  accept_to_pickup_distance  city_name
# 724   645bb146751ce46ce03ec71d                      0.763  Bangalore  \
# 1110  645b8f5c3f9e605f9192f02d                      1.925  Bangalore
# 1950  645b89a7b70c5170c58d26e5                      0.757  Bangalore
# 2963  645b963770e5ce05969cb64d                      1.849  Bangalore
# 3054  645ba0a5de453b02ef335a6f                      1.411  Bangalore
#
#      customer_location_hex_8  customer_location_latitude
# 724          88618925e9fffff                   12.939100  \
# 1110         8861892421fffff                   12.909473
# 1950         88618925ebfffff                   12.942251
# 2963         88618924a5fffff                   12.917027
# 3054         886189251bfffff                   12.925212
#
#       customer_location_longitude  hhmmss hour quarter_hour
# 724                     77.626884  202918   20         2015  \
# 1110                    77.636635  180436   18         1800
# 1950                    77.621309  174015   17         1730
# 2963                    77.582852  183351   18         1830
# 3054                    77.637230  191821   19         1915
#
#      service_obj_service_name time_bucket  weekday  yyyymmdd order_status
# 724                      Auto       20:00        3  20230510          new  \
# 1110                     Auto       18:00        3  20230510          new
# 1950                     Auto       17:59        3  20230510          new
# 2963                     Auto       18:59        3  20230510          new
# 3054                     Auto       19:00        3  20230510          new
#
#                 cancel_reason  eta
# 724             Heavy Traffic  3.0  \
# 1110       Asked to buy items  7.0
# 1950  Unable to swipe Arrived  4.0
# 2963              Long Pickup  7.0
# 3054              Long Pickup  6.0
#
#                                              map_riders pickup_location_hex_8
# 724   ["62578fdd00b5f49e57ad65ea","5cf27fe9ca6e29211...       88618925e9fffff  \
# 1110  ["5de5d28eac56a62ec5e6185a","61d2e630de3a0254a...       886189242dfffff
# 1950  ["5f1f96fdea5a8ba56679a603","623192433a5bed58b...       88618925ebfffff
# 2963  ["61ef89c41772e473ff144182","60fd0164fe2f60ae4...       88618924a5fffff
# 3054  ["623c2999d26cb255e872d4ff","6449f5248fac8ad0b...       886189251bfffff
#
#                     captain_id  estimated_accept_to_pickup_distance
# 724   63e3885d052c8a26c7edbc1e                                776.4  \
# 1110  60d2e01a05468956fbddd94a                               1428.8
# 1950  63a5698d64e8005ff3fcd475                                723.0
# 2963  6116409ef76f8bd4df482a2f                                939.4
# 3054  623c2999d26cb255e872d4ff                                466.1
#
#       updated_epoch    event_type final_order_status
# 724   1683731007711    rider_busy              COBRA
# 1110  1683723161695    rider_busy              COBRA
# 1950  1683721181739  rider_reject      expiry_mapped
# 2963  1683724042726    rider_busy      expiry_mapped
# 3054  1683726895887    rider_busy              COBRA

# %%
df_copy2 = df_copy[df_copy['order_id'].isin(['645bc2a9ec315d1c8d2c0a7d', '645b995ec78d275898f7b767', '645baf766a343d115bead631'])]
df_copy2['timestamp'] = df_copy2['updated_epoch'].apply(lambda x: datetime.fromtimestamp(x/1000))
df_copy2 = df_copy2.sort_values(by = ['order_id', 'updated_epoch'])
df_copy2
# Out:
#                         order_id  accept_to_pickup_distance  city_name
# 34708   645b995ec78d275898f7b767                      0.060  Bangalore  \
# 106595  645b995ec78d275898f7b767                      0.060  Bangalore
# 98465   645baf766a343d115bead631                      1.843  Bangalore
# 97277   645baf766a343d115bead631                      1.843  Bangalore
# 24471   645baf766a343d115bead631                      1.843  Bangalore
# 32063   645baf766a343d115bead631                      1.843  Bangalore
# 129617  645baf766a343d115bead631                      1.843  Bangalore
# 25280   645bc2a9ec315d1c8d2c0a7d                      0.742  Bangalore
# 115031  645bc2a9ec315d1c8d2c0a7d                      0.742  Bangalore
# 88896   645bc2a9ec315d1c8d2c0a7d                      0.742  Bangalore
# 112028  645bc2a9ec315d1c8d2c0a7d                      0.742  Bangalore
#
#        customer_location_hex_8  customer_location_latitude
# 34708          8861892553fffff                   12.916032  \
# 106595         8861892553fffff                   12.916032
# 98465          88618925c3fffff                   12.925103
# 97277          88618925c3fffff                   12.925103
# 24471          88618925c3fffff                   12.925103
# 32063          88618925c3fffff                   12.925103
# 129617         88618925c3fffff                   12.925103
# 25280          88618925e1fffff                   12.945374
# 115031         88618925e1fffff                   12.945374
# 88896          88618925e1fffff                   12.945374
# 112028         88618925e1fffff                   12.945374
#
#         customer_location_longitude  hhmmss hour quarter_hour
# 34708                     77.651622  184718   18         1845  \
# 106595                    77.651622  184718   18         1845
# 98465                     77.612465  202134   20         2015
# 97277                     77.612465  202134   20         2015
# 24471                     77.612465  202134   20         2015
# 32063                     77.612465  202134   20         2015
# 129617                    77.612465  202134   20         2015
# 25280                     77.626076  214329   21         2130
# 115031                    77.626076  214329   21         2130
# 88896                     77.626076  214329   21         2130
# 112028                    77.626076  214329   21         2130
#
#        service_obj_service_name time_bucket  weekday  yyyymmdd order_status
# 34708                      Auto       18:59        3  20230510          new  \
# 106595                     Auto       18:59        3  20230510     onTheWay
# 98465                      Auto       20:00        3  20230510          new
# 97277                      Auto       20:00        3  20230510          new
# 24471                      Auto       20:00        3  20230510          new
# 32063                      Auto       20:00        3  20230510          new
# 129617                     Auto       20:00        3  20230510          new
# 25280                      Auto       21:59        3  20230510          new
# 115031                     Auto       21:59        3  20230510          new
# 88896                      Auto       21:59        3  20230510          new
# 112028                     Auto       21:59        3  20230510          new
#
#                cancel_reason  eta
# 34708   Drop location denied  2.0  \
# 106595  Drop location denied  2.0
# 98465          Heavy Traffic  7.0
# 97277          Heavy Traffic  7.0
# 24471          Heavy Traffic  7.0
# 32063          Heavy Traffic  7.0
# 129617         Heavy Traffic  7.0
# 25280            Long Pickup  3.0
# 115031           Long Pickup  3.0
# 88896            Long Pickup  3.0
# 112028           Long Pickup  3.0
#
#                                                map_riders
# 34708   ["5e49f514b3394b0f2f2a3656","640185a7f22eada02...  \
# 106595  ["5e49f514b3394b0f2f2a3656","640185a7f22eada02...
# 98465   ["62ee41eab6ba02805f667cda","60fbb2d9fe2f607ff...
# 97277   ["62ee41eab6ba02805f667cda","60fbb2d9fe2f607ff...
# 24471   ["62ee41eab6ba02805f667cda","60fbb2d9fe2f607ff...
# 32063   ["62ee41eab6ba02805f667cda","60fbb2d9fe2f607ff...
# 129617  ["62ee41eab6ba02805f667cda","60fbb2d9fe2f607ff...
# 25280   ["62aeeeb267cffab13cea2c33","60fa8812d417d4a5a...
# 115031  ["62aeeeb267cffab13cea2c33","60fa8812d417d4a5a...
# 88896   ["62aeeeb267cffab13cea2c33","610295906cd49257e...
# 112028  ["62aeeeb267cffab13cea2c33","610295906cd49257e...
#
#        pickup_location_hex_8                captain_id
# 34708        8861892553fffff  616cf4654c6ba1f7ced8305a  \
# 106595       8861892553fffff  5e49f514b3394b0f2f2a3656
# 98465        88618925c3fffff  62a306a81284ca0edd09f4cf
# 97277        88618925c3fffff  61cc08719ba37202862da8bc
# 24471        88618925c3fffff  6108eb0fb8bce11a8a1256b3
# 32063        88618925c3fffff  5be26f8f2b706c16e077f1cc
# 129617       88618925c3fffff  60fbb2d9fe2f607ffe869f45
# 25280        88618925e1fffff  6149fa01de864c3f3a034fe1
# 115031       88618925e1fffff  60fa8812d417d4a5a57dfa33
# 88896        88618925e1fffff  60e42d4209aa990f9b40fa77
# 112028       88618925e1fffff  610295906cd49257e63fb1c1
#
#         estimated_accept_to_pickup_distance  updated_epoch    event_type
# 34708                                 681.4  1683724901048  rider_reject  \
# 106595                                177.8  1683724905431      accepted
# 98465                                 968.1  1683730376738  rider_reject
# 97277                                1063.6  1683730380880  rider_reject
# 24471                                1913.8  1683730385758  rider_reject
# 32063                                 769.5  1683730386927  rider_reject
# 129617                                982.5  1683730394652  rider_reject
# 25280                                 332.0  1683735350385  rider_reject
# 115031                                866.4  1683735378636  rider_reject
# 88896                                1725.3  1683735422658    rider_busy
# 112028                                884.2  1683735426098    rider_busy
#
#        final_order_status               timestamp
# 34708             dropped 2023-05-10 18:51:41.048
# 106595            dropped 2023-05-10 18:51:45.431
# 98465               COBRA 2023-05-10 20:22:56.738
# 97277               COBRA 2023-05-10 20:23:00.880
# 24471               COBRA 2023-05-10 20:23:05.758
# 32063               COBRA 2023-05-10 20:23:06.927
# 129617              COBRA 2023-05-10 20:23:14.652
# 25280       expiry_mapped 2023-05-10 21:45:50.385
# 115031      expiry_mapped 2023-05-10 21:46:18.636
# 88896       expiry_mapped 2023-05-10 21:47:02.658
# 112028      expiry_mapped 2023-05-10 21:47:06.098

# %%
df_copy2.to_csv('sample_orders.csv', index = False)

# %%
df_filter_level1
# Out:
#                        order_id  accept_to_pickup_distance  city_name
# 0      645bae48bc677762c758e7c3                        NaN  Bangalore  \
# 1      645bae4bde453b02ef33750e                        NaN  Bangalore
# 2      645bae58888565720ae938e6                        NaN  Bangalore
# 3      645baf8b888565720ae93b0d                      0.438  Bangalore
# 4      645bb05bb70c5170c58d75f8                        NaN  Bangalore
# ...                         ...                        ...        ...
# 30305  645b97f4c78d275898f7b451                        NaN  Bangalore
# 30306  645b9a33c78d275898f7b928                        NaN  Bangalore
# 30307  645b98276a343d115beaa7cc                        NaN  Bangalore
# 30308  645b9830ec315d1c8d2bba01                        NaN  Bangalore
# 30309  645b984a908b9d588b5efc35                        NaN  Bangalore
#
#       customer_location_hex_8  customer_location_latitude
# 0             8861892591fffff                   12.930825  \
# 1             8861892513fffff                   12.931752
# 2             8861892433fffff                   12.906545
# 3             88618925ddfffff                   12.921208
# 4             88618925c1fffff                   12.923099
# ...                       ...                         ...
# 30305         88618924e7fffff                   12.904047
# 30306         88618925c9fffff                   12.916768
# 30307         88618925ebfffff                   12.940269
# 30308         88618925d9fffff                   12.914090
# 30309         8861892513fffff                   12.934335
#
#        customer_location_longitude  hhmmss hour quarter_hour
# 0                        77.580872  201632   20         2015  \
# 1                        77.634494  201635   20         2015
# 2                        77.606756  201648   20         2015
# 3                        77.604073  202155   20         2015
# 4                        77.620018  202523   20         2015
# ...                            ...     ...  ...          ...
# 30305                    77.588232  184116   18         1830
# 30306                    77.623550  185051   18         1845
# 30307                    77.620054  184207   18         1830
# 30308                    77.599678  184216   18         1830
# 30309                    77.628479  184242   18         1830
#
#       service_obj_service_name time_bucket  weekday  yyyymmdd
# 0                         Auto       20:00        3  20230510  \
# 1                         Auto       20:00        3  20230510
# 2                         Auto       20:00        3  20230510
# 3                         Auto       20:00        3  20230510
# 4                         Auto       20:00        3  20230510
# ...                        ...         ...      ...       ...
# 30305                     Auto       18:59        3  20230510
# 30306                     Auto       18:59        3  20230510
# 30307                     Auto       18:59        3  20230510
# 30308                     Auto       18:59        3  20230510
# 30309                     Auto       18:59        3  20230510
#
#             order_status                          cancel_reason  eta
# 0                expired                                   None  7.0  \
# 1                expired                                   None  2.0
# 2      customerCancelled  order cancelled before rider accepted  2.0
# 3                dropped                                   None  2.0
# 4                expired                                   None  0.0
# ...                  ...                                    ...  ...
# 30305  customerCancelled  order cancelled before rider accepted  3.0
# 30306            expired                                   None  2.0
# 30307  customerCancelled  order cancelled before rider accepted  2.0
# 30308            expired                                   None  2.0
# 30309  customerCancelled  order cancelled before rider accepted  2.0
#
#                                               map_riders
# 0      ["60ed2fb613ae1d748eb5528a","6013ae76edd74b702...  \
# 1      ["60f40f138f3479e752195633","63b683460e10cd5a3...
# 2      ["60685591a2f9c56b225129b7","62578fdd00b5f49e5...
# 3      ["62921b26444fa9ba4f782075","610a4a8a06f56f41f...
# 4      ["6442088be2719e34f0671600","62578fdd00b5f49e5...
# ...                                                  ...
# 30305  ["5c7bba9f875c9853625f6f1b","60f165268f34791bc...
# 30306                       ["61067df8a31862ce6b59c3bf"]
# 30307  ["623192433a5bed58b8bec937","60efd298d417d4cd4...
# 30308  ["615163be90fbcb7e26d0ac55","60fd0164fe2f60ae4...
# 30309  ["5e0d6dfb715b3f22b962412a","627df6713645c9d30...
#
#       pickup_location_hex_8                captain_id
# 0           8861892591fffff  62a072577d796770ede1fe5f  \
# 1           8861892513fffff  63d405e015a98c9f1f0db9af
# 2           8861892433fffff
# 3           88618925ddfffff  631b7e788276172360bbb215
# 4           88618925c1fffff  6442088be2719e34f0671600
# ...                     ...                       ...
# 30305       88618924e7fffff  5c7bba9f875c9853625f6f1b
# 30306       88618925c9fffff  6222fe71c1a4e4e1e4645af4
# 30307       88618925ebfffff  643106272548e37cc9e53fa1
# 30308       88618925d1fffff  6116409ef76f8bd4df482a2f
# 30309       8861892513fffff
#
#        estimated_accept_to_pickup_distance  counter      counter_group  count
# 0                                   1060.2      2.0                2.0      1  \
# 1                                   1882.5      6.0  5 or more batches      1
# 2                                      NaN      1.0                1.0      1
# 3                                      NaN      1.0                1.0      1
# 4                                   1122.7      1.0                1.0      1
# ...                                    ...      ...                ...    ...
# 30305                                533.2      1.0                1.0      1
# 30306                               1954.5      3.0                3.0      1
# 30307                               1295.4      2.0                2.0      1
# 30308                               1237.6      4.0                4.0      1
# 30309                                  NaN      1.0                1.0      1
#
#       date new_cancel_reason    expiry_type final_order_status
# 0       10   no_cancellation  expiry_mapped      expiry_mapped
# 1       10   no_cancellation  expiry_mapped      expiry_mapped
# 2       10             COBRA      no_expiry              COBRA
# 3       10   no_cancellation      no_expiry            dropped
# 4       10   no_cancellation  expiry_mapped      expiry_mapped
# ...    ...               ...            ...                ...
# 30305   10             COBRA      no_expiry              COBRA
# 30306   10   no_cancellation  expiry_mapped      expiry_mapped
# 30307   10             COBRA      no_expiry              COBRA
# 30308   10   no_cancellation  expiry_mapped      expiry_mapped
# 30309   10             COBRA      no_expiry              COBRA
#
# [30310 rows x 27 columns]

# %%
#Metrics_pivot
metrics_pivot = pd.pivot_table(df_filter_level1, index = ['yyyymmdd', 'counter_group'], columns = 'final_order_status',
 values = 'count', aggfunc = 'sum', fill_value=0).reset_index().rename_axis(None, axis=1)
metrics_pivot['total'] = metrics_pivot[['COBRA', 'COBRM', 'OCARA', 'aborted', 'dropped', 'expiry_mapped', 'expiry_unmapped']].sum(axis = 1)
metrics_pivot['OCARA%'] = round(metrics_pivot['OCARA']/metrics_pivot['total'], 4)
metrics_pivot['COBRA%'] = round(metrics_pivot['COBRA']/metrics_pivot['total'], 4)
metrics_pivot['COBRM%'] = round(metrics_pivot['COBRM']/metrics_pivot['total'], 4)
metrics_pivot['G2N'] = round(metrics_pivot['dropped']/metrics_pivot['total'], 4)
metrics_pivot['expiry_mapped%'] = round(metrics_pivot['expiry_mapped']/metrics_pivot['total'], 4)
if 'expiry_unmapped' in metrics_pivot.columns:
    metrics_pivot['Stockout%'] = round(metrics_pivot['expiry_unmapped']/metrics_pivot['total'], 4)
else:
    metrics_pivot['Stockout%'] = 0
metrics_df = metrics_pivot[['yyyymmdd', 'counter_group', 'OCARA%', 'COBRA%', 'COBRM%', 'G2N', 'expiry_mapped%', 'Stockout%', 'total']]
metrics_df
# Out:
#    yyyymmdd      counter_group  OCARA%  COBRA%  COBRM%     G2N
# 0  20230510                1.0  0.0252  0.5712   0.002  0.0996  \
# 1  20230510                2.0  0.0412  0.5027   0.000  0.1310
# 2  20230510                3.0  0.0361  0.3607   0.000  0.0835
# 3  20230510                4.0  0.0218  0.1646   0.000  0.0467
# 4  20230510  5 or more batches  0.0163  0.0737   0.000  0.0336
#
#    expiry_mapped%  Stockout%  total
# 0          0.3015     0.0002   9967
# 1          0.3242     0.0000   4732
# 2          0.5193     0.0000   5099
# 3          0.7665     0.0000   5584
# 4          0.8760     0.0000   4911

# %%
#Metrics_pivot
metrics_pivot = pd.pivot_table(df_filter_level1, index = ['yyyymmdd'], columns = 'final_order_status',
 values = 'count', aggfunc = 'sum', fill_value=0).reset_index().rename_axis(None, axis=1)
metrics_pivot['total'] = metrics_pivot[['COBRA', 'COBRM', 'OCARA', 'aborted', 'dropped', 'expiry_mapped', 'expiry_unmapped']].sum(axis = 1)
metrics_pivot['OCARA%'] = round(metrics_pivot['OCARA']/metrics_pivot['total'], 4)
metrics_pivot['COBRA%'] = round(metrics_pivot['COBRA']/metrics_pivot['total'], 4)
metrics_pivot['COBRM%'] = round(metrics_pivot['COBRM']/metrics_pivot['total'], 4)
metrics_pivot['G2N'] = round(metrics_pivot['dropped']/metrics_pivot['total'], 4)
metrics_pivot['expiry_mapped%'] = round(metrics_pivot['expiry_mapped']/metrics_pivot['total'], 4)
if 'expiry_unmapped' in metrics_pivot.columns:
    metrics_pivot['Stockout%'] = round(metrics_pivot['expiry_unmapped']/metrics_pivot['total'], 4)
else:
    metrics_pivot['Stockout%'] = 0
metrics_df = metrics_pivot[['yyyymmdd', 'OCARA%', 'COBRA%', 'COBRM%', 'G2N', 'expiry_mapped%', 'Stockout%', 'total']]
metrics_df
# Out:
#    yyyymmdd  OCARA%  COBRA%  COBRM%     G2N  expiry_mapped%  Stockout%  total
# 0  20230417  0.0504  0.3347  0.0000  0.1658          0.4485        0.0  32180
# 1  20230418  0.0500  0.3283  0.0001  0.1693          0.4516        0.0  32213

# %%
#Get the average ETA and FM
df_dropped = df_filter_level1[df_filter_level1['final_order_status'] == 'dropped']
fm = df_dropped.groupby(['yyyymmdd', 'counter_group'])['accept_to_pickup_distance'].median().reset_index()
fm = fm.rename(columns = {'accept_to_pickup_distance':'FM'})
eta = df_dropped.groupby(['yyyymmdd', 'counter_group'])['eta'].median().reset_index()
metrics_df = metrics_df.merge(fm, on = ['yyyymmdd', 'counter_group'], how = 'left')
metrics_df = metrics_df.merge(eta, on = ['yyyymmdd', 'counter_group'], how = 'left')
metrics_df.head()
# Out:
#    yyyymmdd      counter_group  OCARA%  COBRA%  COBRM%     G2N
# 0  20230417                1.0  0.0612  0.4615  0.0001  0.2649  \
# 1  20230417                2.0  0.0738  0.5051  0.0000  0.2289
# 2  20230417                3.0  0.0566  0.4134  0.0000  0.1649
# 3  20230417                4.0  0.0401  0.2120  0.0000  0.0772
# 4  20230417  5 or more batches  0.0234  0.0816  0.0000  0.0481
#
#    expiry_mapped%  Stockout%  total      FM  eta
# 0          0.2114     0.0001  10454  0.6850  3.0
# 1          0.1916     0.0000   4500  0.8165  3.0
# 2          0.3643     0.0000   4683  0.7500  3.0
# 3          0.6704     0.0000   5480  0.7570  3.0
# 4          0.8467     0.0000   7063  0.7700  3.0

# %%
metrics_df
# Out:
#    yyyymmdd      counter_group  OCARA%  COBRA%  COBRM%     G2N
# 0  20230417                1.0  0.0612  0.4615  0.0001  0.2649  \
# 1  20230417                2.0  0.0738  0.5051  0.0000  0.2289
# 2  20230417                3.0  0.0566  0.4134  0.0000  0.1649
# 3  20230417                4.0  0.0401  0.2120  0.0000  0.0772
# 4  20230417  5 or more batches  0.0234  0.0816  0.0000  0.0481
# 5  20230418                1.0  0.0620  0.4518  0.0004  0.2787
# 6  20230418                2.0  0.0699  0.5101  0.0000  0.2138
# 7  20230418                3.0  0.0625  0.3872  0.0000  0.1792
# 8  20230418                4.0  0.0376  0.2154  0.0000  0.0821
# 9  20230418  5 or more batches  0.0223  0.0902  0.0000  0.0465
#
#    expiry_mapped%  Stockout%  total      FM  eta
# 0          0.2114     0.0001  10454  0.6850  3.0
# 1          0.1916     0.0000   4500  0.8165  3.0
# 2          0.3643     0.0000   4683  0.7500  3.0
# 3          0.6704     0.0000   5480  0.7570  3.0
# 4          0.8467     0.0000   7063  0.7700  3.0
# 5          0.2062     0.0001  10301  0.6870  3.0
# 6          0.2050     0.0000   4419  0.7970  3.0
# 7          0.3707     0.0000   4783  0.7330  3.0
# 8          0.6644     0.0000   5348  0.7980  3.0
# 9          0.8409     0.0000   7362  0.7890  3.0

# %%
metrics_df
# Out:
#    yyyymmdd      counter_group  OCARA%  COBRA%  COBRM%     G2N
# 0  20230417                1.0  0.0612  0.4615  0.0001  0.2649  \
# 1  20230417                2.0  0.0738  0.5051  0.0000  0.2289
# 2  20230417  3 or more batches  0.0377  0.2133  0.0000  0.0891
# 3  20230418                1.0  0.0620  0.4518  0.0004  0.2787
# 4  20230418                2.0  0.0699  0.5101  0.0000  0.2138
# 5  20230418  3 or more batches  0.0380  0.2097  0.0000  0.0936
#
#    expiry_mapped%  Stockout%  total       FM_x     eta_x    FM_y  eta_y
# 0          0.2114     0.0001  10454   3.404303  3.072228  0.6850    3.0
# 1          0.1916     0.0000   4500  16.989028  3.336893  0.8165    3.0
# 2          0.6595     0.0000  17226   3.227829  3.340065  0.7570    3.0
# 3          0.2062     0.0001  10301   3.313941  3.058516  0.6870    3.0
# 4          0.2050     0.0000   4419  16.525852  3.299471  0.7970    3.0
# 5          0.6584     0.0000  17493   7.587716  3.266178  0.7560    3.0
